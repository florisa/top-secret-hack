# %%
# importing pandas as pd 
import pandas as pd 
  
# Making data frame from the csv file 
df = pd.read_excel("Daten.xlsx", sheet_name = "dataset1")

# %%
# To find the correlation among 
# the columns using pearson method 
df.corr(method ='pearson')
# Out:
#                  Force #D  Length #E  Height #F  Press-fit #G  force #H  \
# Force #D         1.000000   0.002572  -0.436142      0.074765  0.321240
# Length #E        0.002572   1.000000   0.071926      0.761748  0.000270
# Height #F       -0.436142   0.071926   1.000000     -0.033300 -0.363914
# Press-fit #G     0.074765   0.761748  -0.033300      1.000000  0.047205
# force #H         0.321240   0.000270  -0.363914      0.047205  1.000000
# Length #I       -0.007201  -0.000798   0.008434      0.061382  0.444459
# Depth #J        -0.138515  -0.015993   0.158367     -0.042232 -0.128950
# depth #K         0.074664  -0.012861  -0.100297     -0.007070  0.150266
# Depth #L        -0.000343  -0.002737  -0.014778     -0.003799  0.020481
# parallelism #M  -0.056289  -0.003684   0.099436     -0.016297 -0.153497
# force #N         0.000337  -0.007423   0.039462     -0.007435 -0.056450
# Length #O        0.068010   0.005089  -0.063214      0.014605 -0.042386
# ...
